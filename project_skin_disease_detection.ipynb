# %% [markdown]
# <a href="https://colab.research.google.com/github/sathwikakonduru/CIP-PROJECT/blob/main/project_skin_disease_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# %%
train_dir = "/content/drive/MyDrive/SkinDataset/train"
test_dir = "/content/drive/MyDrive/SkinDataset/test"

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# %%
train_dir = "/content/drive/MyDrive/skin-disease-datasaet/train_set"
test_dir = "/content/drive/MyDrive/skin-disease-datasaet/test_set"

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
import os

# List contents of MyDrive to help verify the path
print("Contents of /content/drive/MyDrive:")
# !ls -F "/content/drive/MyDrive"
# Out:
# Contents of /content/drive/MyDrive:
#  Classroom/	       PrintStudentExamApplication_copy.pdf
# 'Colab Notebooks'/     skin-disease-datasaet/
# 'Party Invite.gform'

# %% [markdown]
# Please examine the output above and ensure that `SkinDataset/train` and `SkinDataset/test` are present under `/content/drive/MyDrive`. If the paths are different, please update the `train_dir` and `test_dir` variables accordingly. For example, if your dataset is directly under `MyDrive` without a `SkinDataset` folder, you would change the paths to `/content/drive/MyDrive/train` and `/content/drive/MyDrive/test`.

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
import os

# List contents of the dataset directory to verify the structure
print(f"Contents of {train_dir.rsplit('/', 1)[0]}/")
# !ls -F "{train_dir.rsplit('/', 1)[0]}"
# Out:
# Contents of /content/drive/MyDrive/skin-disease-datasaet/
# test_set/  train_set/

# %%
train_data = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

test_data = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

# Redefine the model architecture
model = models.Sequential()
model.add(layers.Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64, (3,3), activation='relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(128, (3,3), activation='relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(train_data.num_classes, activation='softmax'))

# Recompile the model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    train_data,
    epochs=10,
    validation_data=test_data
)
# Out:
# Found 939 images belonging to 8 classes.
# Found 233 images belonging to 8 classes.
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 296s 10s/step - accuracy: 0.1629 - loss: 2.5571 - val_accuracy: 0.2275 - val_loss: 2.0061
# Epoch 2/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.2652 - loss: 1.8941 - val_accuracy: 0.3906 - val_loss: 1.8256
# Epoch 3/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 127s 4s/step - accuracy: 0.3429 - loss: 1.7041 - val_accuracy: 0.4549 - val_loss: 1.6275
# Epoch 4/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 117s 4s/step - accuracy: 0.4132 - loss: 1.5926 - val_accuracy: 0.4721 - val_loss: 1.4887
# Epoch 5/10
# ...

# %%
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='validation')
plt.legend()
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
train_dir = "/content/drive/MyDrive/skin-disease-datasaet/train_set"
test_dir = "/content/drive/MyDrive/skin-disease-datasaet/test_set"

# %%
print(os.listdir(train_dir))
# Out:
# ['FU-ringworm', 'VI-shingles', 'VI-chickenpox', 'FU-nail-fungus', 'BA-impetigo', 'PA-cutaneous-larva-migrans', 'BA- cellulitis', 'FU-athlete-foot']

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_data = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical'
)

test_data = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 939 images belonging to 8 classes.
# Found 233 images belonging to 8 classes.

# %%
from tensorflow.keras.applications import MobileNetV2

base_model = MobileNetV2(input_shape=(224,224,3),
                         include_top=False,
                         weights='imagenet')

base_model.trainable = False

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dense(train_data.num_classes, activation='softmax')
])
# Out:
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_data,
    epochs=10,
    validation_data=test_data
)
# Out:
# Epoch 1/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.6763 - loss: 1.0036 - val_accuracy: 0.8584 - val_loss: 0.4738
# Epoch 2/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9063 - loss: 0.3429 - val_accuracy: 0.8884 - val_loss: 0.3317
# Epoch 3/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 59s 2s/step - accuracy: 0.9297 - loss: 0.2258 - val_accuracy: 0.9013 - val_loss: 0.2681
# Epoch 4/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9499 - loss: 0.1691 - val_accuracy: 0.8884 - val_loss: 0.3255
# Epoch 5/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 59s 2s/step - accuracy: 0.9595 - loss: 0.1447 - val_accuracy: 0.9528 - val_loss: 0.1729
# Epoch 6/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.9702 - loss: 0.1073 - val_accuracy: 0.9313 - val_loss: 0.2138
# Epoch 7/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 59s 2s/step - accuracy: 0.9744 - loss: 0.0857 - val_accuracy: 0.9485 - val_loss: 0.1524
# Epoch 8/10
# ...

# %%
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='validation')
plt.legend()
plt.show()

# %%
loss, acc = model.evaluate(test_data)
print("Test Accuracy:", acc)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.9356 - loss: 0.1633
# Test Accuracy: 0.9356223344802856

# %%
model.save("skin_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-70035340-b91b-4d8b-8d5b-3cb7bdc0eff5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-70035340-b91b-4d8b-8d5b-3cb7bdc0eff5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from tensorflow.keras.preprocessing import image

class_names = list(train_data.class_indices.keys())

for file_name in uploaded.keys():
    img = image.load_img(file_name, target_size=(224,224))
    img_array = image.img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    prediction = model.predict(img_array)

    predicted_class = class_names[np.argmax(prediction)]
    confidence = np.max(prediction) * 100

    plt.imshow(img)
    plt.title(f"{predicted_class} ({confidence:.2f}%)")
    plt.axis('off')
    plt.show()

    print("Predicted Disease:", predicted_class)
    print("Confidence:", confidence, "%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Predicted Disease: PA-cutaneous-larva-migrans
# Confidence: 72.364494 %
